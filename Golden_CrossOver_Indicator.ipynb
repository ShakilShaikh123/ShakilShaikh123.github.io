# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = yf.download('TCS',period='30d' , interval='5m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df['MA20']=df['Adj Close'].rolling(20).mean()
df['MA50']=df['Adj Close'].rolling(50).mean()

# %%
df
# Out:
#                              Open    High    Low   Close  Adj Close  Volume  \
# Datetime
# 2022-03-04 09:30:00-05:00  8.7200  8.7400  8.685  8.6900     8.6900       0
# 2022-03-04 09:35:00-05:00  8.6500  8.7000  8.640  8.6700     8.6700    3072
# 2022-03-04 09:40:00-05:00  8.6500  8.6500  8.590  8.5900     8.5900     478
# 2022-03-04 09:45:00-05:00  8.5465  8.5465  8.520  8.5200     8.5200    2486
# 2022-03-04 09:50:00-05:00  8.4900  8.5100  8.490  8.4999     8.4999    2610
# ...                           ...     ...    ...     ...        ...     ...
# 2022-04-14 15:40:00-04:00  8.2800  8.2950  8.270  8.2950     8.2950    9066
# 2022-04-14 15:45:00-04:00  8.2900  8.3000  8.280  8.2850     8.2850   15711
# 2022-04-14 15:50:00-04:00  8.2800  8.2850  8.250  8.2800     8.2800   13627
# 2022-04-14 15:55:00-04:00  8.2700  8.2800  8.260  8.2700     8.2700   31078
# 2022-04-14 16:00:00-04:00  8.2800  8.2800  8.280  8.2800     8.2800       0
#
#                               MA20    MA50
# Datetime
# 2022-03-04 09:30:00-05:00      NaN     NaN
# 2022-03-04 09:35:00-05:00      NaN     NaN
# 2022-03-04 09:40:00-05:00      NaN     NaN
# 2022-03-04 09:45:00-05:00      NaN     NaN
# 2022-03-04 09:50:00-05:00      NaN     NaN
# ...                            ...     ...
# 2022-04-14 15:40:00-04:00  8.26775  8.2325
# 2022-04-14 15:45:00-04:00  8.26950  8.2320
# 2022-04-14 15:50:00-04:00  8.26950  8.2324
# 2022-04-14 15:55:00-04:00  8.26800  8.2322
# 2022-04-14 16:00:00-04:00  8.26900  8.2322
#
# [2328 rows x 8 columns]

# %%
df=df.dropna()

# %%
df
# Out:
#                             Open   High    Low  Close  Adj Close  Volume  \
# Datetime
# 2022-03-04 13:35:00-05:00  8.365  8.370  8.350  8.360      8.360    2687
# 2022-03-04 13:40:00-05:00  8.350  8.355  8.350  8.355      8.355    1067
# 2022-03-04 13:45:00-05:00  8.320  8.320  8.310  8.310      8.310    2997
# 2022-03-04 13:50:00-05:00  8.315  8.330  8.315  8.330      8.330    1049
# 2022-03-04 13:55:00-05:00  8.330  8.330  8.310  8.310      8.310    2868
# ...                          ...    ...    ...    ...        ...     ...
# 2022-04-14 15:40:00-04:00  8.280  8.295  8.270  8.295      8.295    9066
# 2022-04-14 15:45:00-04:00  8.290  8.300  8.280  8.285      8.285   15711
# 2022-04-14 15:50:00-04:00  8.280  8.285  8.250  8.280      8.280   13627
# 2022-04-14 15:55:00-04:00  8.270  8.280  8.260  8.270      8.270   31078
# 2022-04-14 16:00:00-04:00  8.280  8.280  8.280  8.280      8.280       0
#
#                                MA20      MA50
# Datetime
# 2022-03-04 13:35:00-05:00  8.365565  8.405824
# 2022-03-04 13:40:00-05:00  8.365315  8.399124
# 2022-03-04 13:45:00-05:00  8.362815  8.391924
# 2022-03-04 13:50:00-05:00  8.359315  8.386724
# 2022-03-04 13:55:00-05:00  8.353315  8.382524
# ...                             ...       ...
# 2022-04-14 15:40:00-04:00  8.267750  8.232500
# 2022-04-14 15:45:00-04:00  8.269500  8.232000
# 2022-04-14 15:50:00-04:00  8.269500  8.232400
# 2022-04-14 15:55:00-04:00  8.268000  8.232200
# 2022-04-14 16:00:00-04:00  8.269000  8.232200
#
# [2279 rows x 8 columns]

# %%
df = df[['Adj Close', 'MA20', 'MA50']]

# %%
df
# Out:
#                            Adj Close      MA20      MA50
# Datetime
# 2022-03-04 13:35:00-05:00      8.360  8.365565  8.405824
# 2022-03-04 13:40:00-05:00      8.355  8.365315  8.399124
# 2022-03-04 13:45:00-05:00      8.310  8.362815  8.391924
# 2022-03-04 13:50:00-05:00      8.330  8.359315  8.386724
# 2022-03-04 13:55:00-05:00      8.310  8.353315  8.382524
# ...                              ...       ...       ...
# 2022-04-14 15:40:00-04:00      8.295  8.267750  8.232500
# 2022-04-14 15:45:00-04:00      8.285  8.269500  8.232000
# 2022-04-14 15:50:00-04:00      8.280  8.269500  8.232400
# 2022-04-14 15:55:00-04:00      8.270  8.268000  8.232200
# 2022-04-14 16:00:00-04:00      8.280  8.269000  8.232200
#
# [2279 rows x 3 columns]

# %%
Buy = []
Sell = []

for i in range(len(df)):
    if df.MA20.iloc[i] > df.MA50.iloc[i] \
    and  df.MA20.iloc[i-1] < df.MA50.iloc[i-1]:
        Buy.append(i)
    elif df.MA20.iloc[i] < df.MA50.iloc[i] \
    and df.MA20.iloc[i] > df.MA50[i-1]:
        Sell.append(i)

# %%
Buy
# Out:
# [117,
#  485,
#  564,
#  656,
#  879,
#  915,
#  942,
#  1080,
#  1092,
#  1105,
#  1169,
#  1207,
#  1472,
#  1592,
#  1781,
#  1873,
#  1981,
#  2034,
#  2134,
#  2199,
#  2266]

# %%
Sell
# Out:
# [0, 546, 563, 909, 911, 914, 941, 989, 1091, 1104, 1206, 1941, 1980, 2198]

# %%
plt.figure(figsize=(12,5))
plt.plot(df['Adj Close'], label='Asset Price', c='blue', alpha=0.5)
plt.plot(df['MA20'], label='MA20', c='k', alpha=0.9)
plt.plot(df['MA50'], label='MA50', c='magenta', alpha=0.9)
plt.scatter(df.iloc[Buy].index, df.iloc[Buy]['Adj Close'], marker='^', color='g', s=100)
plt.scatter(df.iloc[Sell].index, df.iloc[Sell]['Adj Close'], marker='v', color='r', s=100)
plt.legend()
plt.show()
